# %%
import warnings
warnings.simplefilter("ignore")

# %%
import geopandas as gpd
import pandas as pd
import numpy as np

# %%
rtc_data = gpd.read_file("../output/rtc_data.geojson")
osm_places = gpd.read_file('../output/osm_places.geojson')
lieuxpublics = gpd.read_file('../input/DonneesVilleQC/vdq-lieupublic.geojson')

# %% [markdown]
# # RTC

# %%
rtc_data.head()
# Out:
#   route_id  direction_id                              trip_headsign stop_id  \
# 0     1-76             1  Aéroport international Jean-Lesage (Nord)  1-1898
# 1     1-76             1  Aéroport international Jean-Lesage (Nord)  1-3515
# 2     1-76             1  Aéroport international Jean-Lesage (Nord)  1-1926
# 3     1-76             1  Aéroport international Jean-Lesage (Nord)  1-1927
# 4     1-76             1  Aéroport international Jean-Lesage (Nord)  1-1928
#
#          stop_name   stop_lat   stop_lon  stop_sequence Parcours      Type  \
# 0    Gare de train  46.754501 -71.297424              1       76  Régulier
# 1    St-Louis/3515  46.756157 -71.296989              2       76  Régulier
# 2       des Hôtels  46.756859 -71.293365              3       76  Régulier
# 3  de Valmont/1927  46.757275 -71.290695              4       76  Régulier
# 4        W.-Stuart  46.759113 -71.287292              5       76  Régulier
#
#                      geometry
# 0   POINT (-71.29742 46.7545)
# 1  POINT (-71.29699 46.75616)
# 2  POINT (-71.29336 46.75686)
# 3   POINT (-71.2907 46.75728)
# 4  POINT (-71.28729 46.75911)

# %% [markdown]
# # Nettoyage données OSM

# %%
osm_places = osm_places[~osm_places['amenity'].isin(['parking', 'bus_station'])] # je decide de ne pas les garder

# %%
# Fusion name et goepy_name (en priorisant name), si je n'ai pas de valeurs manquantes dans la colonne name j attribut cette valeur a geopy_name 
osm_places.loc[osm_places['name'].notna(), 'geopy_name'] = osm_places['name']

# %%
osm_places[osm_places.amenity == 'post_office'].name.unique()
# Out:
# array(['Bureau de poste', None, 'Succursale Poste-Canada',
#        'Bureau de Poste Galeries de la Capitale', 'Succursale Postale',
#        'Sucursale Postale', 'Bureau de Poste Cap Rouge', 'Postes Canada',
#        'UPS', 'Comptoir postal Pharmaprix', 'Brunet - Bureau de poste',
#        'DHL', 'Purolator'], dtype=object)

# %%
osm_places.head()
# Out:
#   element         id                         name    amenity   Category  \
# 0    node   49474611  Caisse Populaire Desjardins       bank  Financial
# 1    node  265847671     La Roulotte du Boulevard  fast_food       Food
# 2    node  275074044                 Petro-Canada       fuel  Transport
# 3    node  275074469                          EKO       fuel  Transport
# 5    node  277667516                       Irving       fuel  Transport
#
#                                        adresse_geopy  \
# 0  Caisse Populaire Desjardins, Rue de l'Universi...
# 1  La Roulotte du Boulevard, Avenue du Bourg-Roya...
# 2  Petro-Canada, Boulevard du Lac, Notre-Dame-des...
# 3  EKO, 65, Boulevard Pierre-Bertrand, Saint-Jose...
# 5  Irving, 750, Boulevard Charest Ouest, Saint-Sa...
#
#                     geopy_name                    geometry
# 0  Caisse Populaire Desjardins   POINT (-71.26978 46.7792)
# 1     La Roulotte du Boulevard  POINT (-71.21603 46.85481)
# 2                 Petro-Canada  POINT (-71.31924 46.91669)
# 3                          EKO  POINT (-71.29489 46.84882)
# 5                       Irving  POINT (-71.24392 46.80468)

# %%
mots_cles_adress = r'^(\d+|Rue|Avenue|Boulevard|Rang|Chemin|Route|Place|Autoroute)'

adresse = osm_places['geopy_name'].str.contains(mots_cles_adress, case=False, regex=True, na=False) # je verifie si le nom ressemble plus a une adresse qu a un nom de place 
nom_valide = osm_places['name'].notna() # si j ai un nom valide dans la colonne name et pas une valeur manquante

# Filtre final, on garde si (c'est un nom de place) OU SI (ce n'est pas une adresse)
place_to_keep = nom_valide | ~ adresse
osm_places = osm_places[place_to_keep]

# %%
pd.DataFrame(osm_places.groupby(['amenity']).size())
# Out:
#                     0
# amenity
# atm                23
# bank               85
# bar                41
# bicycle_rental    163
# cafe              142
# clinic             30
# college            14
# community_centre   56
# dentist            26
# doctors            15
# fast_food         163
# fuel              108
# hospital           13
# ice_cream          11
# kindergarten       18
# library            34
# pharmacy          105
# place_of_worship   85
# post_office        20
# pub                36
# restaurant        444
# school            154
# taxi                2
# townhall            7
# university          6

# %% [markdown]
# # Fusion OSM et données villde de QC ?

# %%
# Projection WGS84 vers le NAD83 MTM Zone 7
osm_places_m = osm_places.to_crs(epsg=32198)
lieuxpublics_m = lieuxpublics.to_crs(epsg=32198)

# Jointure spatiale dans un rayon de 10m : si deux points sont a moins de 10m, cela veut peut etre dire qu'il s'agit de la meme place  
df_merged = gpd.sjoin_nearest(
    osm_places_m, 
    lieuxpublics_m, 
    how="inner",        
    max_distance=10,    
    distance_col="distance_metres"
)
df_merged[['geopy_name', 'NOM_TOPOGRAPHIE', 'distance_metres']].head(30)
# Out:
#                                        geopy_name  \
# 33                       Centre du Nouvel-Horizon
# 50                           Les Loisirs Montcalm
# 92                    Centre culturel Georges Dor
# 92                    Centre culturel Georges Dor
# 119                      Bibliothèque Lebourgneuf
# 136           Bureau d'arrondissement de Beauport
# 156             Bibliothèque Collège-Des-Jésuites
# 157                    Bibliothèque de Neufchâtel
# 438            Centre récréatif de Saint-Rodrigue
# 444                                   La Sablière
# 448    Le Pivot - Centre communautaire des Chutes
# 453                           Chalet Saint-Ignace
# 454                  Bibliothèque du chemin Royal
# 454                  Bibliothèque du chemin Royal
# 462                       Bibliothèque Canardière
# 467          Centre communautaire Jean-Guy-Drolet
# 476                    Bibliothèque Saint-Charles
# 524                                  Chalet Savio
# 670       Centre communautaire de Saint-Sacrement
# 978                                     Quai 1636
# 1030             Centre récréatif Laurence-Perron
# 1041       Centre de loisirs Saint-Thomas-d'Aquin
# 1041       Centre de loisirs Saint-Thomas-d'Aquin
# 1064                                     Le Skyzo
# 1113          Bibliothèque Jean-Baptiste-Duberger
# 1161  Bureau d'arrondissement de la Cité-Limoilou
# 1161  Bureau d'arrondissement de la Cité-Limoilou
# 1247                              Centre Durocher
# 1251                      École Guillaume Mathieu
# 1422                   Chalet Terrasse-du-Bon-Air
#
#                                         NOM_TOPOGRAPHIE  distance_metres
# 33                  École spécialisée du Nouvel Horizon         7.322880
# 50                           Centre de loisirs Montcalm         2.586349
# 92                          Centre culturel Georges-Dor         3.788206
# 92    Bureau d'arrondissement de La Haute-Saint-Charles         3.788206
# 119                    Centre communautaire Lebourgneuf         2.468229
# 136        Stationnement Centre administratif Rainville         6.598937
# 156                   Bibliothèque Collège-des-Jésuites         6.830225
# 157                             Bibliothèque Neufchâtel         0.628762
# 438                     Centre récréatif Saint-Rodrigue         2.161596
# 444                       Centre de loisirs la Sablière         4.604477
# 448                     Centre communautaire des Chutes         7.601448
# 453                                 Chalet Saint-Ignace         1.743945
# 454                        Bibliothèque du Chemin-Royal         2.230750
# 454   Bureau administratif Sociocommunautaire de Bea...         2.230750
# 462                     Bibliothèque Marie-Claire-Blais         4.822377
# 467                Centre communautaire Jean-Guy Drolet         7.836741
# 476                          Bibliothèque Saint-Charles         5.046505
# 524                                        Chalet Savio         1.031279
# 670                Centre de loisirs de Saint-Sacrement         7.984019
# 978   Pavillon de service du Parc nautique de Cap-Rouge         2.323460
# 1030                   Centre récréatif Laurence-Perron         2.377432
# 1041             Centre de loisirs Saint-Thomas-d'Aquin         2.657921
# 1041                     Centre de céramique de Ste-Foy         2.657921
# 1064                     École spécialisée Collège CART         8.352259
# 1113                Bibliothèque Jean-Baptiste-Duberger         4.599592
# 1161        Bureau d'arrondissement de La Cité-Limoilou         9.211514
# 1161               Centre communautaire YMCA-Saint-Roch         9.211514
# 1247              Centre récréatif Monseigneur-Bouffard         8.791424
# 1251                       Parc-école Guillaume-Mathieu         7.098195
# 1422        Chalet des Loisirs du Parc Terrasse Bon-Air         2.759566

# %%
# Il y a bel et bien des doublons Centre culturel Georges Dor" et "Centre culturel Georges-Dor" , il s agit du meme batiment 
# Il y a aussi des mauvais match, "Centre culturel Georges Dor" et "Bureau d'arrondissement..." c'est juste un bureau situé dans le même bâtiment ou un batiment juste à côté

# Pistes / idées a tester
# Utiliser la comparaison textuelle pour supprimer les doublons dans les jeux de données en plus de la distance 
# Creer un score de similarité des textes et fusionner avec les distances pour decider s'il s'agit de la mme place ou non 
# Ce code est une ébauche, donc cette approche est à explorer plus tard

# %%
osm_places.to_file("../output/osm_places_v2.geojson", driver='GeoJSON')
